# %%
pip install pychorus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pychorus import find_and_output_chorus
chorus_start_sec = find_and_output_chorus("kesariya.mp3", r"C:\Users\Lenovo\Desktop\kesariya.mp3", 30)
# Out:
# Best chorus found at 2 min 43.73 sec

# %%
from pychorus import find_and_output_chorus
chorus_start_sec = find_and_output_chorus(r"[iSongs.info] 05 - Vellipomaakey.mp3", r"C:\Users\Lenovo\Desktop\Vellipomakey.mp3", 20)

# %%
from pychorus import create_chroma
from pychorus.similarity_matrix import TimeTimeSimilarityMatrix, TimeLagSimilarityMatrix

chroma, _, sr, _ = create_chroma(r"kesariya.mp3")
time_time_similarity = TimeTimeSimilarityMatrix(chroma, sr)
time_lag_similarity = TimeLagSimilarityMatrix(chroma, sr)

# Visualize the results
time_time_similarity.display()
time_lag_similarity.display()

# %%
import pychorus
chroma, d, _, _ = pychorus.create_chroma(r"kesariya.mp3")

# %%
chroma
# Out:
# array([[0.033788  , 0.03780862, 0.13430509, ..., 0.38755533, 0.5087944 ,
#         0.54338723],
#        [0.02496111, 0.01147615, 0.02276156, ..., 0.5063431 , 0.5727713 ,
#         0.5696135 ],
#        [0.02656014, 0.01048996, 0.00473747, ..., 1.        , 0.91657877,
#         0.84183764],
#        ...,
#        [0.00682769, 0.00268026, 0.00194063, ..., 0.3228013 , 0.56187856,
#         0.59326094],
#        [0.00356275, 0.00157834, 0.00146108, ..., 0.39086628, 0.50792444,
#         0.5229944 ],
#        [0.01414557, 0.01061597, 0.02226593, ..., 0.5300107 , 0.7963507 ,
#         0.7832018 ]], dtype=float32)

# %%
d
# Out:
# array([4.916838e-15, 7.637881e-15, 7.108821e-15, ..., 0.000000e+00,
#        0.000000e+00, 0.000000e+00], dtype=float32)
